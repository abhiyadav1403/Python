# %% [markdown]
# Print:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,5+1):
    for j in range(1, i+1):
        print("*", end=(" "))

    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# Reverse Star Pattern
#
# Output:
#
# *****
# ****
# ***
# **
# *

# %%
for i in range(5,0,-1):
    for j in range(i):
        print("*", end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %% [markdown]
# Number Triangle
#
# Output:
#
# 1
# 12
# 123
# 1234
# 12345

# %%
for i in range(1, 5+1):
    for j in range(1, i+1):
        print( j, end="")
    print()
# Out:
# 1
# 12
# 123
# 1234
# 12345

# %% [markdown]
# Reverse Number Triangle
#
# Output:
#
# 5
# 54
# 543
# 5432
# 54321

# %%
for i in range(5):
    for j in range(5, 5-i-1,-1):
        print(j, end="")
    print()
# Out:
# 5
# 54
# 543
# 5432
# 54321

# %% [markdown]
# Repeated Number Pattern
#
# Output:
#
# 1
# 22
# 333
# 4444
# 55555

# %%
for i in range(1,6):
    for j in range(i):
        print(i,end="")
    print()
# Out:
# 1
# 22
# 333
# 4444
# 55555

# %% [markdown]
# My challenge for you
#
# Without looking at the answer, solve this pattern:
#
# A
# BB
# CCC
# DDDD
# EEEEE

# %%
# num = ("A", "B", "C", "D", "E")
for i in range(1,5+1):
    for j in range(i):
        print(chr(64+i), end="")
    print()
# Out:
# A
# BB
# CCC
# DDDD
# EEEEE

# %% [markdown]
# A
# AB
# ABC
# ABCD
# ABCDE

# %%
for i in range(1,6):
    for j in  range(1,i+1):
        print(chr(64+j), end="")
    print()
# Out:
# A
# AB
# ABC
# ABCD
# ABCDE

# %% [markdown]
# Can you solve this without help?
#
# E
# DE
# CDE
# BCDE
# ABCDE

# %%
for i in range(5):
    for j in range(69-i, 70):
        print(chr(j), end="")
    print()
# Out:
# E
# DE
# CDE
# BCDE
# ABCDE
