# %% [markdown]
# # Module: Logging Assignments
# ## Lesson: Logging
# ### Assignment 1: Basic Logging
#
# 1. Write a Python function to create a basic logger that logs messages to a file named `app.log`.

# %%
import logging

def basic_logger():
    logging.basicConfig(filename='app.log', level=logging.DEBUG)
    logging.debug('This is a debug message')
    logging.info('This is an info message')
    logging.warning('This is a warning message')
    logging.error('This is an error message')
    logging.critical('This is a critical message')

# Test the function
basic_logger()

# %% [markdown]
# 2. Modify the function to log messages of levels: DEBUG, INFO, WARNING, ERROR, and CRITICAL.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 2: Logging with Different Handlers
#
# 1. Write a Python function to create a logger that logs messages to both a file named `app.log` and the console.

# %%
def logger_with_handlers():
    logger = logging.getLogger('my_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('app.log')
    console_handler = logging.StreamHandler()
    
    file_handler.setLevel(logging.DEBUG)
    console_handler.setLevel(logging.DEBUG)
    
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_handlers()
# Out:
# 2026-08-05 12:26:14,795 - my_logger - DEBUG - This is a debug message
# 2026-08-05 12:26:14,796 - my_logger - INFO - This is an info message
# 2026-08-05 12:26:14,797 - my_logger - WARNING - This is a warning message
# 2026-08-05 12:26:14,798 - my_logger - ERROR - This is an error message
# 2026-08-05 12:26:14,799 - my_logger - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different logging levels for the file and console handlers.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 3: Formatting Log Messages
#
# 1. Write a Python function to create a logger with a custom log message format that includes the timestamp, logging level, and message.

# %%
def logger_with_custom_format():
    logger = logging.getLogger('custom_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('custom_app.log')
    console_handler = logging.StreamHandler()
    
    formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    console_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_custom_format()
# Out:
# 2026-08-05 12:26:14,823 - DEBUG - This is a debug message
# 2026-08-05 12:26:14,824 - INFO - This is an info message
# 2026-08-05 12:26:14,826 - WARNING - This is a warning message
# 2026-08-05 12:26:14,828 - ERROR - This is an error message
# 2026-08-05 12:26:14,829 - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the function to use different formats for the file and console handlers.

# %%
def logger_with_different_formats():
    logger = logging.getLogger('multi_format_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('multi_format_app.log')
    console_handler = logging.StreamHandler()
    
    file_formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    console_formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(file_formatter)
    console_handler.setFormatter(console_formatter)
    
    logger.addHandler(file_handler)
    logger.addHandler(console_handler)
    
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
logger_with_different_formats()
# Out:
# 2026-08-05 12:26:14,843 - DEBUG - This is a debug message
# 2026-08-05 12:26:14,844 - INFO - This is an info message
# 2026-08-05 12:26:14,845 - WARNING - This is a warning message
# 2026-08-05 12:26:14,846 - ERROR - This is an error message
# 2026-08-05 12:26:14,848 - CRITICAL - This is a critical message

# %% [markdown]
# ### Assignment 4: Rotating Log Files
#
# 1. Write a Python function to create a logger that uses a rotating file handler, which creates a new log file when the current log file reaches a certain size.

# %%
from logging.handlers import RotatingFileHandler

def logger_with_rotating_file_handler():
    logger = logging.getLogger('rotating_logger')
    logger.setLevel(logging.DEBUG)
    
    rotating_handler = RotatingFileHandler('rotating_app.log', maxBytes=2000, backupCount=5)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    rotating_handler.setFormatter(formatter)
    
    logger.addHandler(rotating_handler)
    
    for i in range(100):
        logger.debug('This is debug message number {}'.format(i))

# Test the function
logger_with_rotating_file_handler()

# %% [markdown]
# 2. Modify the function to keep a specified number of backup log files.

# %%
# The modification is already included in the above function with backupCount=5.

# %% [markdown]
# ### Assignment 5: Logging Exceptions
#
# 1. Write a Python function that logs an exception stack trace to a log file when an exception occurs.

# %%
def log_exception():
    logger = logging.getLogger('exception_logger')
    logger.setLevel(logging.ERROR)
    
    file_handler = logging.FileHandler('exception_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    try:
        1 / 0
    except Exception as e:
        logger.exception("An exception occurred")

# Test the function
log_exception()

# %% [markdown]
# 2. Modify the function to log the stack trace at the ERROR level.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 6: Contextual Logging
#
# 1. Write a Python function to create a logger that includes contextual information (e.g., function name, line number) in the log messages.

# %%
def logger_with_context():
    logger = logging.getLogger('context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    def test_func():
        logger.debug('This is a debug message')
        logger.info('This is an info message')
        logger.warning('This is a warning message')
        logger.error('This is an error message')
        logger.critical('This is a critical message')
    
    test_func()

# Test the function
logger_with_context()

# %% [markdown]
# 2. Modify the function to include additional contextual information (e.g., user ID, session ID).

# %%
def logger_with_additional_context(user_id, session_id):
    logger = logging.getLogger('additional_context_logger')
    logger.setLevel(logging.DEBUG)
    
    file_handler = logging.FileHandler('additional_context_app.log')
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d - UserID: %(user_id)s - SessionID: %(session_id)s')
    file_handler.setFormatter(formatter)
    
    logger.addHandler(file_handler)
    
    extra = {'user_id': user_id, 'session_id': session_id}
    
    def test_func():
        logger.debug('This is a debug message', extra=extra)
        logger.info('This is an info message', extra=extra)
        logger.warning('This is a warning message', extra=extra)
        logger.error('This is an error message', extra=extra)
        logger.critical('This is a critical message', extra=extra)
    
    test_func()

# Test the function
logger_with_additional_context('user123', 'session456')

# %% [markdown]
# ### Assignment 7: Configuring Logging with a Dictionary
#
# 1. Write a Python function to configure logging using a dictionary. The configuration should include handlers for both file and console logging.

# %%
import logging.config

def configure_logging_with_dict():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            },
            'detailed': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s - %(funcName)s - %(lineno)d'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'dict_config_app.log',
                'formatter': 'detailed',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)
    logger = logging.getLogger('')
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
configure_logging_with_dict()
# Out:
# 2026-08-05 12:26:14,960 - root - DEBUG - This is a debug message
# 2026-08-05 12:26:14,961 - root - INFO - This is an info message
# 2026-08-05 12:26:14,962 - root - WARNING - This is a warning message
# 2026-08-05 12:26:14,963 - root - ERROR - This is an error message
# 2026-08-05 12:26:14,964 - root - CRITICAL - This is a critical message

# %% [markdown]
# 2. Modify the dictionary to include different logging levels and formats for each handler.

# %%
# The modification is already included in the above function.

# %% [markdown]
# ### Assignment 8: Logging in a Multi-Module Application
#
# 1. Write a Python script that sets up logging for a multi-module application. Each module should have its own logger.

# %% [markdown]
# #### File: `main.py`

# %%
import logging
from module_a import module_a_function
from module_b import module_b_function

def setup_logging():
    log_config = {
        'version': 1,
        'formatters': {
            'default': {
                'format': '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
            }
        },
        'handlers': {
            'file': {
                'class': 'logging.FileHandler',
                'filename': 'multi_module_app.log',
                'formatter': 'default',
                'level': 'DEBUG'
            },
            'console': {
                'class': 'logging.StreamHandler',
                'formatter': 'default',
                'level': 'DEBUG'
            }
        },
        'root': {
            'handlers': ['file', 'console'],
            'level': 'DEBUG'
        }
    }
    logging.config.dictConfig(log_config)

# Main script
if __name__ == '__main__':
    setup_logging()
    logger = logging.getLogger(__name__)
    logger.info('Main module started')
    module_a_function()
    module_b_function()
    logger.info('Main module finished')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 import logging
# ----> 2 from module_a import module_a_function
#       3 from module_b import module_b_function
#       5 def setup_logging():
#
# ModuleNotFoundError: No module named 'module_a'

# %% [markdown]
# #### File: `module_a.py`

# %%
import logging

def module_a_function():
    logger = logging.getLogger(__name__)
    logger.info('Module A function started')
    logger.debug('This is a debug message from Module A')
    logger.info('Module A function finished')

# %% [markdown]
# #### File: `module_b.py`

# %%
import logging

def module_b_function():
    logger = logging.getLogger(__name__)
    logger.info('Module B function started')
    logger.debug('This is a debug message from Module B')
    logger.info('Module B function finished')

# %% [markdown]
# 2. Modify the script to propagate log messages from each module's logger to a root logger that handles logging to a file.

# %%
# The modification is already included in the above scripts. Each module's logger messages propagate to the root logger.

# %% [markdown]
# ### Assignment 9: Logging Performance
#
# 1. Write a Python script to benchmark the performance of logging with different handlers (e.g., file handler, console handler, rotating file handler).

# %%
import logging
import time
from logging.handlers import RotatingFileHandler

def benchmark_logging_performance():
    logger = logging.getLogger('performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler
    file_handler = logging.FileHandler('performance_file.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # Console handler
    console_handler = logging.StreamHandler()
    console_handler.setLevel(logging.DEBUG)
    logger.addHandler(console_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('Console handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(console_handler)

    # Rotating file handler
    rotating_handler = RotatingFileHandler('performance_rotating.log', maxBytes=2000, backupCount=5)
    rotating_handler.setLevel(logging.DEBUG)
    logger.addHandler(rotating_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('Rotating file handler logging time: {} seconds'.format(end_time - start_time))
    logger.removeHandler(rotating_handler)

# Test the function
benchmark_logging_performance()
# Out:
# 2026-08-01 15:15:11,839 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,842 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,843 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,843 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,844 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,845 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,845 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,846 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,847 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,848 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,849 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,850 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,851 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,851 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,852 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,853 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,853 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:11,854 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,014 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,015 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,016 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,017 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,018 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,019 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,020 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,021 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,022 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,023 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,023 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,024 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,025 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,026 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,027 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,028 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,029 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,030 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,031 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,032 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,033 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,034 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,034 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,035 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,036 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,037 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,039 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,042 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,043 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,044 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,045 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,046 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,047 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,048 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,049 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,050 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,052 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,053 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,054 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,056 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,057 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,058 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,058 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,059 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,061 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,061 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,062 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,063 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,064 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,065 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,066 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,067 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,068 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,070 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,071 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,073 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,074 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,075 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,077 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,078 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,079 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,080 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,081 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,082 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,083 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,084 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,085 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,088 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,090 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,091 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,092 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,093 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,093 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,094 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,095 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,096 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,096 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,097 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,098 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,098 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,099 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,100 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,100 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,101 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,102 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,103 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,103 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,104 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,105 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,106 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,107 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,108 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,110 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,110 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,111 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,112 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,113 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,114 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,115 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,116 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,117 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,117 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,118 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,120 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,121 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,122 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,123 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,123 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,124 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,125 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,126 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,127 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,127 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,128 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,129 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,130 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,131 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,132 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,133 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,134 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,135 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,136 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,137 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,138 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,139 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,141 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,141 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,142 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,143 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,144 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,145 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,145 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,146 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,147 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,147 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,148 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,149 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,150 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,150 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,152 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,153 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,154 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,155 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,156 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,157 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,158 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,158 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,159 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,160 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,161 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12
- performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,549 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,549 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,551 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,552 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,553 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,554 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,555 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,556 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,557 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,558 - performance_logger - DEBUG - This is a debug message
# 2026-08-01 15:15:12,558 - performance_logger - DEBUG - This is a debug message
# ...
# This is a debug message
# 2026-08-01 15:15:38,658 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,660 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,663 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,667 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,670 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,673 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,677 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,681 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,684 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,687 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,691 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,693 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,696 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,698 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,701 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,706 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,710 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,712 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,716 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,719 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,721 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,725 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,727 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,731 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,734 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,737 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,740 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,742 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,744 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,746 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,751 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,753 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,755 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,757 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,761 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,763 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,765 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,769 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,772 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,775 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,777 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,779 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,783 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,785 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,788 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,790 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,793 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,795 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,797 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,801 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,803 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,805 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,807 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,809 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,814 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,818 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,820 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,823 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,826 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,828 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,831 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,833 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,835 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,837 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,839 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,842 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,844 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,847 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,849 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,851 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,855 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,858 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,860 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,861 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,863 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,868 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,870 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,872 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,877 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,879 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,882 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,884 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,886 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,888 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,891 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,893 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,896 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,899 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,903 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,906 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,908 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,911 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,915 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,917 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,920 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,923 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,925 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,927 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,929 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,934 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,936 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,939 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,942 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,944 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,946 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,948 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,949 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,951 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,955 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,958 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,960 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,962 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,964 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,969 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,971 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,973 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,975 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,976 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,978 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,981 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,985 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,990 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,992 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,994 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,997 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:38,999 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,001 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,005 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,009 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,012 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,014 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,017 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,019 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,021 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,023 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,028 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,030 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,032 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,036 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,039 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,042 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,044 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,046 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,048 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,052 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,055 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,058 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,060 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,061 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,063 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,075 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,078 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,081 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,084 - performance_logger - DEBUG - This is a debug message
# This is a debug message
# 2026-08-01 15:15:39,088 - performance_logger - DEBUG - This is a debug message

# %% [markdown]
# 2. Modify the script to compare the performance of logging with and without message formatting.

# %%
def benchmark_logging_formatting_performance():
    logger = logging.getLogger('formatting_performance_logger')
    logger.setLevel(logging.DEBUG)

    # File handler without formatting
    file_handler = logging.FileHandler('performance_no_format.log')
    file_handler.setLevel(logging.DEBUG)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time without formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

    # File handler with formatting
    file_handler = logging.FileHandler('performance_with_format.log')
    file_handler.setLevel(logging.DEBUG)
    formatter = logging.Formatter('%(asctime)s - %(name)s - %(levelname)s - %(message)s')
    file_handler.setFormatter(formatter)
    logger.addHandler(file_handler)

    start_time = time.time()
    for i in range(10000):
        logger.debug('This is a debug message')
    end_time = time.time()
    print('File handler logging time with formatting: {} seconds'.format(end_time - start_time))
    logger.removeHandler(file_handler)

# Test the function
benchmark_logging_formatting_performance()

# %% [markdown]
# ### Assignment 10: Advanced Logging Configuration
#
# 1. Write a Python function to configure logging using an external configuration file (e.g., `logging.conf`). The configuration should include handlers for file and console logging.

# %% [markdown]
# #### File: `logging.conf`

# %%
[loggers]
keys=root

[handlers]
keys=fileHandler,consoleHandler

[formatters]
keys=defaultFormatter

[logger_root]
level=DEBUG
handlers=fileHandler,consoleHandler

[handler_fileHandler]
class=FileHandler
level=DEBUG
formatter=defaultFormatter
args=('advanced_logging_app.log', 'a')

[handler_consoleHandler]
class=StreamHandler
level=DEBUG
formatter=defaultFormatter
args=(sys.stdout,)

[formatter_defaultFormatter]
format=%(asctime)s - %(name)s - %(levelname)s - %(message)s
# Out:
#   Cell In[1], line 15
#     class=FileHandler
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# #### File: `main.py`

# %%
import logging.config

def setup_logging_from_file():
    logging.config.fileConfig('logging.conf')
    logger = logging.getLogger(__name__)
    logger.debug('This is a debug message')
    logger.info('This is an info message')
    logger.warning('This is a warning message')
    logger.error('This is an error message')
    logger.critical('This is a critical message')

# Test the function
setup_logging_from_file()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 13
#      10     logger.critical('This is a critical message')
#      12 # Test the function
# ---> 13 setup_logging_from_file()
#
# Cell In[2], line 4, in setup_logging_from_file()
#       3 def setup_logging_from_file():
# ----> 4     logging.config.fileConfig('logging.conf')
#       5     logger = logging.getLogger(__name__)
#       6     logger.debug('This is a debug message')
#
# File c:\Users\infinix\anaconda3\Lib\logging\config.py:66, in fileConfig(fname, defaults, disable_existing_loggers, encoding)
#      64 if isinstance(fname, str):
#      65     if not os.path.exists(fname):
# ---> 66         raise FileNotFoundError(f"{fname} doesn't exist")
#      67     elif not os.path.getsize(fname):
#      68         raise RuntimeError(f'{fname} is an empty file')
#
# FileNotFoundError: logging.conf doesn't exist

# %% [markdown]
# 2. Modify the configuration file to use different logging levels and formats for each handler.

# %%
# The modification is already included in the above configuration file.
